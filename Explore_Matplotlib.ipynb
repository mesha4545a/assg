# %% [markdown]
# <a href="https://colab.research.google.com/github/mesha4545a/assg/blob/main/Explore_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
plt.style.use('seaborn-whitegrid')
plt.style.use('seaborn-white')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("tips")

df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.sample(5)
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 174       16.82  4.0    Male    Yes   Sun  Dinner     2
# 133       12.26  2.0  Female     No  Thur   Lunch     2
# 92         5.75  1.0  Female    Yes   Fri  Dinner     2
# 50        12.54  2.5    Male     No   Sun  Dinner     2
# 115       17.31  3.5  Female     No   Sun  Dinner     2

# %%
df.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Dinner', 'Lunch']

# %%
df['size']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
x = df.loc[df['sex'] == 'Male']
y = df.loc[df['sex'] == 'Female']

# %%
plt.figure(figsize=(15,5))
plt.plot(x.tip,'#6666ff', label = 'male tips')  
plt.plot(y.tip,'#FF69B4', label = 'femail tips')
plt.title("male vs femail tips")
plt.axis('tight')
plt.legend();   # specify color by name

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x="tip", y="total_bill",
                hue="sex",
                data=df
                );

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(data=df, x="total_bill", y="tip", hue="size", size="size");

# %%
plt.figure(figsize=(15,5))
df["day"].value_counts().plot.pie()
plt.title("Distribution of busy days");

# %%
plt.figure(figsize=(15,5))
df["time"].value_counts().plot.pie()
plt.title("Distribution of busy time");

# %%
plt.figure(figsize=(15,5))
kwargs = dict(histtype='stepfilled', bins=40)
#plt.hist(df.size, **kwargs)
plt.hist(df.tip, **kwargs, label= "tips")
plt.hist(df.total_bill, **kwargs,label= "total bils")
plt.title("total bils and tips")
plt.legend();
